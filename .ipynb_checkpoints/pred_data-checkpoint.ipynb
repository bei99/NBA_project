# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('predicted_data.csv')

# %%
data = data.drop('Unnamed: 0', 1)
data = data.drop('index', 1)
data.set_index(['GAME_DATE', 'HOME', 'AWAY'])
# Out:
#                       Results  Odds1  Odds2    Score  prediction
# GAME_DATE  HOME AWAY
# 2020-02-08 MIN  LAC       1.0   5.12   1.19  142:115    0.323551
# 2013-11-22 DET  ATL       0.0   1.59   2.46    89:96    0.460407
# 2013-03-29 MIN  OKC       1.0   4.08   1.26   101:93    0.348161
# 2016-01-05 LAL  GSW       0.0  12.44   1.05   88:109    0.350684
# 2014-04-05 WAS  CHI       0.0   1.74   2.14    78:96    0.494033
# ...                       ...    ...    ...      ...         ...
# 2019-02-07 BOS  LAL       0.0   1.24   4.33  128:129    0.818541
# 2020-02-08 TOR  BKN       1.0   1.39   3.15  119:118    0.719916
# 2019-03-21 WAS  DEN       0.0   4.11   1.26  108:113    0.472558
# 2010-03-12 MIA  CHI       1.0   1.11   7.29   108:95    0.651020
# 2018-02-09 PHI  NOP       1.0   1.43   2.98   100:82    0.669453
#
# [2860 rows x 5 columns]

# %%
data['odds1_true'] = 1/ pd.to_numeric(data['Odds1'],errors='coerce')
data['odds2_true'] = 1/ pd.to_numeric(data['Odds2'], errors='coerce')
data['odds_total'] = data['odds1_true'] + data['odds2_true']
data['pred_away'] = 1 - pd.to_numeric(data['prediction'], errors='coerce')
data.rename(columns={'prediction': 'pred_home'}, inplace=True)
data
# Out:
#       Results   GAME_DATE HOME AWAY  Odds1  Odds2    Score  pred_home  \
# 0         1.0  2020-02-08  MIN  LAC   5.12   1.19  142:115   0.323551
# 1         0.0  2013-11-22  DET  ATL   1.59   2.46    89:96   0.460407
# 2         1.0  2013-03-29  MIN  OKC   4.08   1.26   101:93   0.348161
# 3         0.0  2016-01-05  LAL  GSW  12.44   1.05   88:109   0.350684
# 4         0.0  2014-04-05  WAS  CHI   1.74   2.14    78:96   0.494033
# ...       ...         ...  ...  ...    ...    ...      ...        ...
# 2855      0.0  2019-02-07  BOS  LAL   1.24   4.33  128:129   0.818541
# 2856      1.0  2020-02-08  TOR  BKN   1.39   3.15  119:118   0.719916
# 2857      0.0  2019-03-21  WAS  DEN   4.11   1.26  108:113   0.472558
# 2858      1.0  2010-03-12  MIA  CHI   1.11   7.29   108:95   0.651020
# 2859      1.0  2018-02-09  PHI  NOP   1.43   2.98   100:82   0.669453
#
#       odds1_true  odds2_true  odds_total  pred_away
# 0       0.195312    0.840336    1.035649   0.676449
# 1       0.628931    0.406504    1.035435   0.539593
# 2       0.245098    0.793651    1.038749   0.651839
# 3       0.080386    0.952381    1.032767   0.649316
# 4       0.574713    0.467290    1.042002   0.505967
# ...          ...         ...         ...        ...
# 2855    0.806452    0.230947    1.037398   0.181459
# 2856    0.719424    0.317460    1.036885   0.280084
# 2857    0.243309    0.793651    1.036960   0.527442
# 2858    0.900901    0.137174    1.038075   0.348980
# 2859    0.699301    0.335570    1.034871   0.330547
#
# [2860 rows x 12 columns]

# %%
cols = list(data.columns.values)
cols
# Out:
# ['Results',
#  'GAME_DATE',
#  'HOME',
#  'AWAY',
#  'Odds1',
#  'Odds2',
#  'Score',
#  'pred_home',
#  'odds1_true',
#  'odds2_true',
#  'odds_total',
#  'pred_away']

# %%
data = data[[
 'GAME_DATE',
 'HOME',
 'AWAY','Score',
 'Odds1',
 'Odds2',
 'odds_total',
 'odds1_true',
 'odds2_true',
 'pred_home',
 'pred_away',
    'Results']]
data.set_index(['GAME_DATE', 'HOME', 'AWAY'], inplace=True)
data
# Out:
#                         Score  Odds1  Odds2  odds_total  odds1_true  \
# GAME_DATE  HOME AWAY
# 2020-02-08 MIN  LAC   142:115   5.12   1.19    1.035649    0.195312
# 2013-11-22 DET  ATL     89:96   1.59   2.46    1.035435    0.628931
# 2013-03-29 MIN  OKC    101:93   4.08   1.26    1.038749    0.245098
# 2016-01-05 LAL  GSW    88:109  12.44   1.05    1.032767    0.080386
# 2014-04-05 WAS  CHI     78:96   1.74   2.14    1.042002    0.574713
# ...                       ...    ...    ...         ...         ...
# 2019-02-07 BOS  LAL   128:129   1.24   4.33    1.037398    0.806452
# 2020-02-08 TOR  BKN   119:118   1.39   3.15    1.036885    0.719424
# 2019-03-21 WAS  DEN   108:113   4.11   1.26    1.036960    0.243309
# 2010-03-12 MIA  CHI    108:95   1.11   7.29    1.038075    0.900901
# 2018-02-09 PHI  NOP    100:82   1.43   2.98    1.034871    0.699301
#
#                       odds2_true  pred_home  pred_away  Results
# GAME_DATE  HOME AWAY
# 2020-02-08 MIN  LAC     0.840336   0.323551   0.676449      1.0
# 2013-11-22 DET  ATL     0.406504   0.460407   0.539593      0.0
# 2013-03-29 MIN  OKC     0.793651   0.348161   0.651839      1.0
# 2016-01-05 LAL  GSW     0.952381   0.350684   0.649316      0.0
# 2014-04-05 WAS  CHI     0.467290   0.494033   0.505967      0.0
# ...                          ...        ...        ...      ...
# 2019-02-07 BOS  LAL     0.230947   0.818541   0.181459      0.0
# 2020-02-08 TOR  BKN     0.317460   0.719916   0.280084      1.0
# 2019-03-21 WAS  DEN     0.793651   0.472558   0.527442      0.0
# 2010-03-12 MIA  CHI     0.137174   0.651020   0.348980      1.0
# 2018-02-09 PHI  NOP     0.335570   0.669453   0.330547      1.0
#
# [2860 rows x 9 columns]

# %%
percentile = [0.6, 0.7,0.8, 0.9]
for i in percentile:
    print(data.pred_home.quantile(i))

    #print(data.pred_away.quantile(i))
# Out:
# 0.6272191524505615
# 0.6739056229591369
# 0.721245527267456
# 0.7707576334476471

# %%
data.hist(column='pred_home')
data.hist(column='pred_away')
# Out:
# array([[<AxesSubplot:title={'center':'pred_away'}>]], dtype=object)

# %%
data['pred_home_t'] = np.where(data['pred_home']> 0.5, data['pred_home'], 0.0)
data['pred_away_t'] = np.where(data['pred_away']> 0.5, data['pred_away'], 0.0)
data
# Out:
# <ipython-input-291-8fdc5456788d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['pred_home_t'] = np.where(data['pred_home']> 0.5, data['pred_home'], 0.0)
# <ipython-input-291-8fdc5456788d>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['pred_away_t'] = np.where(data['pred_away']> 0.5, data['pred_away'], 0.0)
#                         Score  Odds1  Odds2  odds_total  odds1_true  \
# GAME_DATE  HOME AWAY
# 2020-02-08 MIN  LAC   142:115   5.12   1.19    1.035649    0.195312
# 2013-11-22 DET  ATL     89:96   1.59   2.46    1.035435    0.628931
# 2013-03-29 MIN  OKC    101:93   4.08   1.26    1.038749    0.245098
# 2016-01-05 LAL  GSW    88:109  12.44   1.05    1.032767    0.080386
# 2014-04-05 WAS  CHI     78:96   1.74   2.14    1.042002    0.574713
# ...                       ...    ...    ...         ...         ...
# 2019-02-07 BOS  LAL   128:129   1.24   4.33    1.037398    0.806452
# 2020-02-08 TOR  BKN   119:118   1.39   3.15    1.036885    0.719424
# 2019-03-21 WAS  DEN   108:113   4.11   1.26    1.036960    0.243309
# 2010-03-12 MIA  CHI    108:95   1.11   7.29    1.038075    0.900901
# 2018-02-09 PHI  NOP    100:82   1.43   2.98    1.034871    0.699301
#
#                       odds2_true  pred_home  pred_away  Results  pred_home_t  \
# GAME_DATE  HOME AWAY
# 2020-02-08 MIN  LAC     0.840336   0.323551   0.676449      1.0     0.000000
# 2013-11-22 DET  ATL     0.406504   0.460407   0.539593      0.0     0.000000
# 2013-03-29 MIN  OKC     0.793651   0.348161   0.651839      1.0     0.000000
# 2016-01-05 LAL  GSW     0.952381   0.350684   0.649316      0.0     0.000000
# 2014-04-05 WAS  CHI     0.467290   0.494033   0.505967      0.0     0.000000
# ...                          ...        ...        ...      ...          ...
# 2019-02-07 BOS  LAL     0.230947   0.818541   0.181459      0.0     0.818541
# 2020-02-08 TOR  BKN     0.317460   0.719916   0.280084      1.0     0.719916
# 2019-03-21 WAS  DEN     0.793651   0.472558   0.527442      0.0     0.000000
# 2010-03-12 MIA  CHI     0.137174   0.651020   0.348980      1.0     0.651020
# 2018-02-09 PHI  NOP     0.335570   0.669453   0.330547      1.0     0.669453
#
#                       pred_away_t
# GAME_DATE  HOME AWAY
# 2020-02-08 MIN  LAC      0.676449
# 2013-11-22 DET  ATL      0.539593
# 2013-03-29 MIN  OKC      0.651839
# 2016-01-05 LAL  GSW      0.649316
# 2014-04-05 WAS  CHI      0.505967
# ...                           ...
# 2019-02-07 BOS  LAL      0.000000
# 2020-02-08 TOR  BKN      0.000000
# 2019-03-21 WAS  DEN      0.527442
# 2010-03-12 MIA  CHI      0.000000
# 2018-02-09 PHI  NOP      0.000000
#
# [2860 rows x 11 columns]

# %%
data[['odds1_true', 'odds2_true']].astype(float)
data['odds1_true_02'] = pd.to_numeric(data['odds1_true'],errors='coerce') + 0.02
data['odds2_true_02'] = pd.to_numeric(data['odds2_true'],errors='coerce') + 0.02

# %%
data
# Out:
#                         Score  Odds1  Odds2  odds_total  odds1_true  \
# GAME_DATE  HOME AWAY
# 2020-02-08 MIN  LAC   142:115   5.12   1.19    1.035649    0.195312
# 2013-11-22 DET  ATL     89:96   1.59   2.46    1.035435    0.628931
# 2013-03-29 MIN  OKC    101:93   4.08   1.26    1.038749    0.245098
# 2016-01-05 LAL  GSW    88:109  12.44   1.05    1.032767    0.080386
# 2014-04-05 WAS  CHI     78:96   1.74   2.14    1.042002    0.574713
# ...                       ...    ...    ...         ...         ...
# 2019-02-07 BOS  LAL   128:129   1.24   4.33    1.037398    0.806452
# 2020-02-08 TOR  BKN   119:118   1.39   3.15    1.036885    0.719424
# 2019-03-21 WAS  DEN   108:113   4.11   1.26    1.036960    0.243309
# 2010-03-12 MIA  CHI    108:95   1.11   7.29    1.038075    0.900901
# 2018-02-09 PHI  NOP    100:82   1.43   2.98    1.034871    0.699301
#
#                       odds2_true  pred_home  pred_away  Results  pred_home_t  \
# GAME_DATE  HOME AWAY
# 2020-02-08 MIN  LAC     0.840336   0.323551   0.676449      1.0     0.000000
# 2013-11-22 DET  ATL     0.406504   0.460407   0.539593      0.0     0.000000
# 2013-03-29 MIN  OKC     0.793651   0.348161   0.651839      1.0     0.000000
# 2016-01-05 LAL  GSW     0.952381   0.350684   0.649316      0.0     0.000000
# 2014-04-05 WAS  CHI     0.467290   0.494033   0.505967      0.0     0.000000
# ...                          ...        ...        ...      ...          ...
# 2019-02-07 BOS  LAL     0.230947   0.818541   0.181459      0.0     0.818541
# 2020-02-08 TOR  BKN     0.317460   0.719916   0.280084      1.0     0.719916
# 2019-03-21 WAS  DEN     0.793651   0.472558   0.527442      0.0     0.000000
# 2010-03-12 MIA  CHI     0.137174   0.651020   0.348980      1.0     0.651020
# 2018-02-09 PHI  NOP     0.335570   0.669453   0.330547      1.0     0.669453
#
#                       pred_away_t  odds1_true_02  odds2_true_02
# GAME_DATE  HOME AWAY
# 2020-02-08 MIN  LAC      0.676449       0.215312       0.860336
# 2013-11-22 DET  ATL      0.539593       0.648931       0.426504
# 2013-03-29 MIN  OKC      0.651839       0.265098       0.813651
# 2016-01-05 LAL  GSW      0.649316       0.100386       0.972381
# 2014-04-05 WAS  CHI      0.505967       0.594713       0.487290
# ...                           ...            ...            ...
# 2019-02-07 BOS  LAL      0.000000       0.826452       0.250947
# 2020-02-08 TOR  BKN      0.000000       0.739424       0.337460
# 2019-03-21 WAS  DEN      0.527442       0.263309       0.813651
# 2010-03-12 MIA  CHI      0.000000       0.920901       0.157174
# 2018-02-09 PHI  NOP      0.000000       0.719301       0.355570
#
# [2860 rows x 13 columns]

# %%
def roi1h(df):
    if df['pred_home_t'] > df['odds1_true_02']:
        if df['pred_home_t'] >= 0.5 and df['pred_home_t'] <0.6:
            return df['Results'] * df['Odds1'] * 1 -1
def roi2h(df):
    if df['pred_home_t'] > df['odds1_true_02']:
        if df['pred_home_t']> 0.6 and df['pred_home_t'] <=0.7:
            return df['Results'] * df['Odds1'] * 2 - 2
def roi3h(df):
    if df['pred_home_t'] > df['odds1_true_02']:
        if df['pred_home_t']> 0.7:
            return df['Results'] * df['Odds1'] * 3 -3
def roi1a(df):
    if df['pred_away_t'] > df['odds2_true_02']:
        if df['pred_away_t']>= 0.5 and df['pred_away_t'] <0.6:
            return (1- df['Results']) * df['Odds2'] * 1 -1
def roi2a(df):
    if df['pred_away_t'] > df['odds2_true_02']:
        if df['pred_away_t']> 0.6 and df['pred_away_t'] <=0.7:
            return (1 - df['Results']) * df['Odds2'] * 2 -2
def roi3a(df):
    if df['pred_away_t'] > df['odds2_true_02']:
        if df['pred_away_t']> 0.7:
            return (1 - df['Results']) * df['Odds2'] * 3 -3

data['roi1h'] = data.apply(roi1h, axis=1)
data['roi2h'] = data.apply(roi2h, axis=1)
data['roi3h'] = data.apply(roi3h, axis=1)
data['roi1a'] = data.apply(roi1a, axis=1)
data['roi2a'] = data.apply(roi2a, axis=1)
data['roi3a'] = data.apply(roi3a, axis=1)
data['roi_total'] = data.fillna(0)['roi1h'] + data.fillna(0)['roi2h'] + data.fillna(0)['roi3h'] + data.fillna(0)['roi1a'] + data.fillna(0)['roi2a'] + data.fillna(0)['roi3a']
data['roi_total_cum'] = data['roi_total'].cumsum()
data
# Out:
#                         Score  Odds1  Odds2  odds_total  odds1_true  \
# GAME_DATE  HOME AWAY
# 2020-02-08 MIN  LAC   142:115   5.12   1.19    1.035649    0.195312
# 2013-11-22 DET  ATL     89:96   1.59   2.46    1.035435    0.628931
# 2013-03-29 MIN  OKC    101:93   4.08   1.26    1.038749    0.245098
# 2016-01-05 LAL  GSW    88:109  12.44   1.05    1.032767    0.080386
# 2014-04-05 WAS  CHI     78:96   1.74   2.14    1.042002    0.574713
# ...                       ...    ...    ...         ...         ...
# 2019-02-07 BOS  LAL   128:129   1.24   4.33    1.037398    0.806452
# 2020-02-08 TOR  BKN   119:118   1.39   3.15    1.036885    0.719424
# 2019-03-21 WAS  DEN   108:113   4.11   1.26    1.036960    0.243309
# 2010-03-12 MIA  CHI    108:95   1.11   7.29    1.038075    0.900901
# 2018-02-09 PHI  NOP    100:82   1.43   2.98    1.034871    0.699301
#
#                       odds2_true  pred_home  pred_away  Results  pred_home_t  \
# GAME_DATE  HOME AWAY
# 2020-02-08 MIN  LAC     0.840336   0.323551   0.676449      1.0     0.000000
# 2013-11-22 DET  ATL     0.406504   0.460407   0.539593      0.0     0.000000
# 2013-03-29 MIN  OKC     0.793651   0.348161   0.651839      1.0     0.000000
# 2016-01-05 LAL  GSW     0.952381   0.350684   0.649316      0.0     0.000000
# 2014-04-05 WAS  CHI     0.467290   0.494033   0.505967      0.0     0.000000
# ...                          ...        ...        ...      ...          ...
# 2019-02-07 BOS  LAL     0.230947   0.818541   0.181459      0.0     0.818541
# 2020-02-08 TOR  BKN     0.317460   0.719916   0.280084      1.0     0.719916
# 2019-03-21 WAS  DEN     0.793651   0.472558   0.527442      0.0     0.000000
# 2010-03-12 MIA  CHI     0.137174   0.651020   0.348980      1.0     0.651020
# 2018-02-09 PHI  NOP     0.335570   0.669453   0.330547      1.0     0.669453
#
#                       ...  odds1_true_02  odds2_true_02  roi1h  roi2h  roi3h  \
# GAME_DATE  HOME AWAY  ...
# 2020-02-08 MIN  LAC   ...       0.215312       0.860336    NaN    NaN    NaN
# 2013-11-22 DET  ATL   ...       0.648931       0.426504    NaN    NaN    NaN
# 2013-03-29 MIN  OKC   ...       0.265098       0.813651    NaN    NaN    NaN
# 2016-01-05 LAL  GSW   ...       0.100386       0.972381    NaN    NaN    NaN
# 2014-04-05 WAS  CHI   ...       0.594713       0.487290    NaN    NaN    NaN
# ...                   ...            ...            ...    ...    ...    ...
# 2019-02-07 BOS  LAL   ...       0.826452       0.250947    NaN    NaN    NaN
# 2020-02-08 TOR  BKN   ...       0.739424       0.337460    NaN    NaN    NaN
# 2019-03-21 WAS  DEN   ...       0.263309       0.813651    NaN    NaN    NaN
# 2010-03-12 MIA  CHI   ...       0.920901       0.157174    NaN    NaN    NaN
# 2018-02-09 PHI  NOP   ...       0.719301       0.355570    NaN    NaN    NaN
#
#                       roi1a  roi2a  roi3a  roi_total  roi_total_cum
# GAME_DATE  HOME AWAY
# 2020-02-08 MIN  LAC     NaN    NaN    NaN       0.00           0.00
# 2013-11-22 DET  ATL    1.46    NaN    NaN       1.46           1.46
# 2013-03-29 MIN  OKC     NaN    NaN    NaN       0.00           1.46
# 2016-01-05 LAL  GSW     NaN    NaN    NaN       0.00           1.46
# 2014-04-05 WAS  CHI    1.14    NaN    NaN       1.14           2.60
# ...                     ...    ...    ...        ...            ...
# 2019-02-07 BOS  LAL     NaN    NaN    NaN       0.00          56.84
# 2020-02-08 TOR  BKN     NaN    NaN    NaN       0.00          56.84
# 2019-03-21 WAS  DEN     NaN    NaN    NaN       0.00          56.84
# 2010-03-12 MIA  CHI     NaN    NaN    NaN       0.00          56.84
# 2018-02-09 PHI  NOP     NaN    NaN    NaN       0.00          56.84
#
# [2860 rows x 21 columns]

# %%
data.reset_index(inplace=True)
# Out:
#        GAME_DATE HOME AWAY    Score  Odds1  Odds2  odds_total  odds1_true  \
# 0     2020-02-08  MIN  LAC  142:115   5.12   1.19    1.035649    0.195312
# 1     2013-11-22  DET  ATL    89:96   1.59   2.46    1.035435    0.628931
# 2     2013-03-29  MIN  OKC   101:93   4.08   1.26    1.038749    0.245098
# 3     2016-01-05  LAL  GSW   88:109  12.44   1.05    1.032767    0.080386
# 4     2014-04-05  WAS  CHI    78:96   1.74   2.14    1.042002    0.574713
# ...          ...  ...  ...      ...    ...    ...         ...         ...
# 2855  2019-02-07  BOS  LAL  128:129   1.24   4.33    1.037398    0.806452
# 2856  2020-02-08  TOR  BKN  119:118   1.39   3.15    1.036885    0.719424
# 2857  2019-03-21  WAS  DEN  108:113   4.11   1.26    1.036960    0.243309
# 2858  2010-03-12  MIA  CHI   108:95   1.11   7.29    1.038075    0.900901
# 2859  2018-02-09  PHI  NOP   100:82   1.43   2.98    1.034871    0.699301
#
#       odds2_true  pred_home  ...  odds1_true_02  odds2_true_02  roi1h  roi2h  \
# 0       0.840336   0.323551  ...       0.215312       0.860336    NaN    NaN
# 1       0.406504   0.460407  ...       0.648931       0.426504    NaN    NaN
# 2       0.793651   0.348161  ...       0.265098       0.813651    NaN    NaN
# 3       0.952381   0.350684  ...       0.100386       0.972381    NaN    NaN
# 4       0.467290   0.494033  ...       0.594713       0.487290    NaN    NaN
# ...          ...        ...  ...            ...            ...    ...    ...
# 2855    0.230947   0.818541  ...       0.826452       0.250947    NaN    NaN
# 2856    0.317460   0.719916  ...       0.739424       0.337460    NaN    NaN
# 2857    0.793651   0.472558  ...       0.263309       0.813651    NaN    NaN
# 2858    0.137174   0.651020  ...       0.920901       0.157174    NaN    NaN
# 2859    0.335570   0.669453  ...       0.719301       0.355570    NaN    NaN
#
#       roi3h  roi1a  roi2a  roi3a  roi_total  roi_total_cum
# 0       NaN    NaN    NaN    NaN       0.00           0.00
# 1       NaN   1.46    NaN    NaN       1.46           1.46
# 2       NaN    NaN    NaN    NaN       0.00           1.46
# 3       NaN    NaN    NaN    NaN       0.00           1.46
# 4       NaN   1.14    NaN    NaN       1.14           2.60
# ...     ...    ...    ...    ...        ...            ...
# 2855    NaN    NaN    NaN    NaN       0.00          56.84
# 2856    NaN    NaN    NaN    NaN       0.00          56.84
# 2857    NaN    NaN    NaN    NaN       0.00          56.84
# 2858    NaN    NaN    NaN    NaN       0.00          56.84
# 2859    NaN    NaN    NaN    NaN       0.00          56.84
#
# [2860 rows x 24 columns]

# %%
import matplotlib.pyplot as plt

data['roi_total'] = data['roi_total'].replace(0, np.nan)
data['roi_total_cum'] = data['roi_total'].cumsum()
data['roi1h_cum'] = data['roi1h'].cumsum()
data['roi2h_cum'] = data['roi2h'].cumsum()
data['roi3h_cum'] = data['roi3h'].cumsum()
data['roi1a_cum'] = data['roi1a'].cumsum()
data['roi2a_cum'] = data['roi2a'].cumsum()
data['roi3a_cum'] = data['roi3a'].cumsum()
data_roi = data[['roi1h_cum','roi2h_cum','roi3h_cum','roi1a_cum','roi2a_cum','roi3a_cum','roi_total_cum','GAME_DATE']]
#data = data.sort_values(by='GAME_DATE')
data_roi.set_index('GAME_DATE', inplace=True)
#sns.lineplot(data = data_roi, x='GAME_DATE')
data_roi
# Out:
#             roi1h_cum  roi2h_cum  roi3h_cum  roi1a_cum  roi2a_cum  roi3a_cum  \
# GAME_DATE
# 2008-10-29        NaN        NaN       -3.0        NaN        NaN        NaN
# 2008-11-18        NaN        NaN        NaN        NaN        NaN        NaN
# 2008-11-19        NaN        NaN        NaN        NaN        NaN        NaN
# 2008-11-21        NaN        NaN        NaN        NaN        NaN        NaN
# 2008-11-22        NaN        NaN        NaN       -1.0        NaN        NaN
# ...               ...        ...        ...        ...        ...        ...
# 2022-04-10        NaN        NaN        NaN        NaN        NaN        NaN
# 2022-04-10        NaN        NaN        NaN        NaN        1.8        NaN
# 2022-04-10        NaN        NaN        NaN        NaN        NaN        NaN
# 2022-04-10        NaN        NaN        NaN        NaN        NaN        NaN
# 2022-04-10        NaN        NaN        NaN        NaN        NaN        NaN
#
#             roi_total_cum
# GAME_DATE
# 2008-10-29          -3.00
# 2008-11-18            NaN
# 2008-11-19            NaN
# 2008-11-21            NaN
# 2008-11-22          -4.00
# ...                   ...
# 2022-04-10            NaN
# 2022-04-10          56.84
# 2022-04-10            NaN
# 2022-04-10            NaN
# 2022-04-10            NaN
#
# [2860 rows x 7 columns]

# %%
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.lineplot(data = data_roi, x= )
# Out:
# <AxesSubplot:xlabel='GAME_DATE'>
